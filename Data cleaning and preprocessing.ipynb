# %% [markdown]
# # 📊 Hotel Revenue 2024 Data Analysis and Visualization using python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv("hotelrevenue.csv")
df
# Out:
#            Date  Month  Weekday  Season  Holiday  Marketing_Spend  Revenue  \
# 0    01/01/2024      1        1  Winter        1            50000    80000
# 1    02/01/2024      1        2  Winter        0            60000    85000
# 2    03/01/2024      1        3  Winter        0            70000    90000
# 3    04/01/2024      1        4  Winter        1            50000    80000
# 4    05/01/2024      1        5  Winter        0            60000    85000
# ..          ...    ...      ...     ...      ...              ...      ...
# 104  27/07/2024      7        5  Summer        0            50000    78000
# 105  28/07/2024      7        6  Summer        0            55000    81000
# 106  29/07/2024      7        7  Summer        0            65000    87000
# 107  30/07/2024      7        1  Summer        0            70000    91000
# 108  31/07/2024      7        2  Summer        0            50000    78000
#
# ...

# %% [markdown]
# # Data Exploration

# %%
df.head() # fist 5 Columns
# Out:
#          Date  Month  Weekday  Season  Holiday  Marketing_Spend  Revenue  \
# 0  01/01/2024      1        1  Winter        1            50000    80000
# 1  02/01/2024      1        2  Winter        0            60000    85000
# 2  03/01/2024      1        3  Winter        0            70000    90000
# 3  04/01/2024      1        4  Winter        1            50000    80000
# 4  05/01/2024      1        5  Winter        0            60000    85000
#
#    Room_Revenue  Occupancy_Rate  ADR  ...  Occupancy_Managed_Guests  \
# 0         45000            0.75  120  ...                        75
# 1         48000            0.78  125  ...                        78
# 2         49000            0.80  130  ...                        80
# 3         45000            0.75  120  ...                        75
# 4         48000            0.78  125  ...                        78
#
#    RevPAR_All  Occupancy_All Room_Revenue_All Total_Revenue  \
# ...

# %%
df.tail() # Last 5 Columns
# Out:
#            Date  Month  Weekday  Season  Holiday  Marketing_Spend  Revenue  \
# 104  27/07/2024      7        5  Summer        0            50000    78000
# 105  28/07/2024      7        6  Summer        0            55000    81000
# 106  29/07/2024      7        7  Summer        0            65000    87000
# 107  30/07/2024      7        1  Summer        0            70000    91000
# 108  31/07/2024      7        2  Summer        0            50000    78000
#
#      Room_Revenue  Occupancy_Rate  ADR  ...  Occupancy_Managed_Guests  \
# 104         43000            0.73  115  ...                        73
# 105         44000            0.75  120  ...                        75
# 106         46000            0.78  125  ...                        78
# 107         48000            0.80  130  ...                        80
# 108         43000            0.73  115  ...                        73
#
#      RevPAR_All  Occupancy_All Room_Revenue_All Total_Revenue  \
# ...

# %% [markdown]
# ### Check Unique Values for all the columns

# %%
df["Month"].unique()
# Out:
# array([1, 2, 3, 7])

# %%
df.nunique()
# Out:
# Date                        109
# Month                         4
# Weekday                       7
# Season                        3
# Holiday                       2
# Marketing_Spend               5
# Revenue                      15
# Room_Revenue                  8
# Occupancy_Rate                9
# ADR                          12
# RevPAR                       16
# Available_Rooms               6
# Reserved_Rooms                7
# Booking_Channel               2
# Guest_Type                    2
# Market_Segment                8
# Guest_Country                 6
# Complaints                    4
# Compliment                    3
# Bookings                      5
# No_Shows                      3
# Cancellations                 2
# Checkouts                     4
# New_Bookings                  3
# Checkins                      2
# Average_Review_Score          5
# Revenue_Managed_Guests       15
# RevPAR_Managed_Guests         5
# Occupancy_Managed_Guests      9
# ...

# %%
df["Bookings"].value_counts()
# Out:
# Bookings
# 10    44
# 8     32
# 9     27
# 7      5
# 11     1
# Name: count, dtype: int64

# %% [markdown]
# # Memory Usage

# %%
df.memory_usage()
# Out:
# Index                        132
# Date                        1962
# Month                        872
# Weekday                      872
# Season                      1526
# Holiday                      872
# Marketing_Spend              872
# Revenue                      872
# Room_Revenue                 872
# Occupancy_Rate               872
# ADR                          872
# RevPAR                       872
# Available_Rooms              872
# Reserved_Rooms               872
# Booking_Channel             1385
# Guest_Type                  1682
# Market_Segment               872
# Guest_Country               1351
# Complaints                   872
# Compliment                   872
# Bookings                     872
# No_Shows                     872
# Cancellations                872
# Checkouts                    872
# New_Bookings                 872
# Checkins                     872
# Average_Review_Score         872
# Revenue_Managed_Guests       872
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=109, step=1)

# %%
df.size
# Out:
# 4142

# %% [markdown]
# ### Basic Information about the Dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      109 non-null    str
#  1   Month                     109 non-null    int64
#  2   Weekday                   109 non-null    int64
#  3   Season                    109 non-null    str
#  4   Holiday                   109 non-null    int64
#  5   Marketing_Spend           109 non-null    int64
#  6   Revenue                   109 non-null    int64
#  7   Room_Revenue              109 non-null    int64
#  8   Occupancy_Rate            109 non-null    float64
#  9   ADR                       109 non-null    int64
#  10  RevPAR                    109 non-null    float64
#  11  Available_Rooms           109 non-null    int64
#  12  Reserved_Rooms            109 non-null    int64
#  13  Booking_Channel           109 non-null    str
# ...

# %%
df.shape
# Out:
# (109, 38)

# %%
df.columns
# Out:
# Index(['Date', 'Month', 'Weekday', 'Season', 'Holiday', 'Marketing_Spend',
#        'Revenue', 'Room_Revenue', 'Occupancy_Rate', 'ADR', 'RevPAR',
#        'Available_Rooms', 'Reserved_Rooms', 'Booking_Channel', 'Guest_Type',
#        'Market_Segment', 'Guest_Country', 'Complaints', 'Compliment',
#        'Bookings', 'No_Shows', 'Cancellations', 'Checkouts', 'New_Bookings',
#        'Checkins', 'Average_Review_Score', 'Revenue_Managed_Guests',
#        'RevPAR_Managed_Guests', 'Occupancy_Managed_Guests', 'RevPAR_All',
#        'Occupancy_All', 'Room_Revenue_All', 'Total_Revenue',
#        'Operating_Expenses', 'Fixed_Costs', 'Variable_Costs', 'Total_Costs',
#        'Profit'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Date                            str
# Month                         int64
# Weekday                       int64
# Season                          str
# Holiday                       int64
# Marketing_Spend               int64
# Revenue                       int64
# Room_Revenue                  int64
# Occupancy_Rate              float64
# ADR                           int64
# RevPAR                      float64
# Available_Rooms               int64
# Reserved_Rooms                int64
# Booking_Channel                 str
# Guest_Type                      str
# Market_Segment              float64
# Guest_Country                   str
# Complaints                    int64
# Compliment                    int64
# Bookings                      int64
# No_Shows                      int64
# Cancellations                 int64
# Checkouts                     int64
# New_Bookings                  int64
# Checkins                      int64
# Average_Review_Score        float64
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Check Missing Value on all Columns

# %%
df.isnull().sum()
# Out:
# Date                          0
# Month                         0
# Weekday                       0
# Season                        0
# Holiday                       0
# Marketing_Spend               0
# Revenue                       0
# Room_Revenue                  0
# Occupancy_Rate                0
# ADR                           0
# RevPAR                        0
# Available_Rooms               0
# Reserved_Rooms                0
# Booking_Channel               0
# Guest_Type                    0
# Market_Segment                0
# Guest_Country                 0
# Complaints                    0
# Compliment                    0
# Bookings                      0
# No_Shows                      0
# Cancellations                 0
# Checkouts                     0
# New_Bookings                  0
# Checkins                      0
# Average_Review_Score          0
# Revenue_Managed_Guests        0
# RevPAR_Managed_Guests         0
# Occupancy_Managed_Guests      0
# ...

# %% [markdown]
# #### Statistical Overview of all the integer columns for the imputation of the values

# %%
# Descibe only integer value
df.describe()
# Out:
#             Month     Weekday     Holiday  Marketing_Spend       Revenue  \
# count  109.000000  109.000000  109.000000       109.000000    109.000000
# mean     3.266055    3.908257    0.119266     59954.128440  84917.431193
# std      2.406173    2.030058    0.325598      8093.647853   4501.292901
# min      1.000000    1.000000    0.000000     50000.000000  78000.000000
# 25%      1.000000    2.000000    0.000000     50000.000000  80000.000000
# 50%      2.000000    4.000000    0.000000     60000.000000  85000.000000
# 75%      7.000000    6.000000    0.000000     70000.000000  90000.000000
# max      7.000000    7.000000    1.000000     70000.000000  93000.000000
#
#        Room_Revenue  Occupancy_Rate         ADR      RevPAR  Available_Rooms  \
# count    109.000000      109.000000  109.000000  109.000000       109.000000
# mean   47009.174312        0.774862  124.743119   95.289083        31.376147
# std     2057.035861        0.023516    5.191524    7.906691         1.451621
# ...

# %%
# Descibe all integer and string value
df.describe(include="all")
# Out:
#               Date       Month     Weekday  Season     Holiday  \
# count          109  109.000000  109.000000     109  109.000000
# unique         109         NaN         NaN       3         NaN
# top     01/01/2024         NaN         NaN  Winter         NaN
# freq             1         NaN         NaN      60         NaN
# mean           NaN    3.266055    3.908257     NaN    0.119266
# std            NaN    2.406173    2.030058     NaN    0.325598
# min            NaN    1.000000    1.000000     NaN    0.000000
# 25%            NaN    1.000000    2.000000     NaN    0.000000
# 50%            NaN    2.000000    4.000000     NaN    0.000000
# 75%            NaN    7.000000    6.000000     NaN    0.000000
# max            NaN    7.000000    7.000000     NaN    1.000000
#
#         Marketing_Spend       Revenue  Room_Revenue  Occupancy_Rate  \
# count        109.000000    109.000000    109.000000      109.000000
# unique              NaN           NaN           NaN             NaN
# ...

# %% [markdown]
# # Fill profit for all rows

# %%
#Fill Profit for all rows
df["Profit"] = df["Total_Revenue"] - df["Total_Costs"]
df
# Out:
#            Date  Month  Weekday  Season  Holiday  Marketing_Spend  Revenue  \
# 0    01/01/2024      1        1  Winter        1            50000    80000
# 1    02/01/2024      1        2  Winter        0            60000    85000
# 2    03/01/2024      1        3  Winter        0            70000    90000
# 3    04/01/2024      1        4  Winter        1            50000    80000
# 4    05/01/2024      1        5  Winter        0            60000    85000
# ..          ...    ...      ...     ...      ...              ...      ...
# 104  27/07/2024      7        5  Summer        0            50000    78000
# 105  28/07/2024      7        6  Summer        0            55000    81000
# 106  29/07/2024      7        7  Summer        0            65000    87000
# 107  30/07/2024      7        1  Summer        0            70000    91000
# 108  31/07/2024      7        2  Summer        0            50000    78000
#
# ...

# %%
df["Profit"] # Check Profit Column
# Out:
# 0      35000
# 1      43000
# 2      44000
# 3      35000
# 4      43000
#        ...
# 104    28000
# 105    28500
# 106    32000
# 107    35000
# 108    28000
# Name: Profit, Length: 109, dtype: int64

# %%
df.isnull().sum() # verify missing value:
# Out:
# Date                        0
# Month                       0
# Weekday                     0
# Season                      0
# Holiday                     0
# Marketing_Spend             0
# Revenue                     0
# Room_Revenue                0
# Occupancy_Rate              0
# ADR                         0
# RevPAR                      0
# Available_Rooms             0
# Reserved_Rooms              0
# Booking_Channel             0
# Guest_Type                  0
# Market_Segment              0
# Guest_Country               0
# Complaints                  0
# Compliment                  0
# Bookings                    0
# No_Shows                    0
# Cancellations               0
# Checkouts                   0
# New_Bookings                0
# Checkins                    0
# Average_Review_Score        0
# Revenue_Managed_Guests      0
# RevPAR_Managed_Guests       0
# Occupancy_Managed_Guests    0
# RevPAR_All                  0
# Occupancy_All               0
# ...

# %% [markdown]
# # Check DUPLICATE RECORD

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# Length: 109, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Indexing and Slicing

# %%
df.loc[0] #Labels
# Out:
# Date                        01/01/2024
# Month                                1
# Weekday                              1
# Season                          Winter
# Holiday                              1
# Marketing_Spend                  50000
# Revenue                          80000
# Room_Revenue                     45000
# Occupancy_Rate                    0.75
# ADR                                120
# RevPAR                            90.0
# Available_Rooms                     30
# Reserved_Rooms                      10
# Booking_Channel                 Direct
# Guest_Type                     Leisure
# Market_Segment                    0.25
# Guest_Country                      USA
# Complaints                           2
# Compliment                           0
# Bookings                            10
# No_Shows                             1
# Cancellations                        0
# Checkouts                            8
# New_Bookings                         2
# ...

# %%
df.loc[0:20]
# Out:
#           Date  Month  Weekday  Season  Holiday  Marketing_Spend  Revenue  \
# 0   01/01/2024      1        1  Winter        1            50000    80000
# 1   02/01/2024      1        2  Winter        0            60000    85000
# 2   03/01/2024      1        3  Winter        0            70000    90000
# 3   04/01/2024      1        4  Winter        1            50000    80000
# 4   05/01/2024      1        5  Winter        0            60000    85000
# 5   06/01/2024      1        6  Winter        0            70000    90000
# 6   07/01/2024      1        7  Winter        0            50000    80000
# 7   08/01/2024      1        1  Winter        0            60000    85000
# 8   09/01/2024      1        2  Winter        0            70000    90000
# 9   10/01/2024      1        3  Winter        0            50000    80000
# 10  11/01/2024      1        4  Winter        1            60000    85000
# 11  12/01/2024      1        5  Winter        0            70000    90000
# ...

# %%
df.iloc[25] # Index at location
# Out:
# Date                        26/01/2024
# Month                                1
# Weekday                              5
# Season                          Winter
# Holiday                              0
# Marketing_Spend                  60000
# Revenue                          85000
# Room_Revenue                     48000
# Occupancy_Rate                    0.78
# ADR                                125
# RevPAR                            97.5
# Available_Rooms                     32
# Reserved_Rooms                       8
# Booking_Channel                    OTA
# Guest_Type                    Business
# Market_Segment                     0.2
# Guest_Country                       UK
# Complaints                           1
# Compliment                           1
# Bookings                             9
# No_Shows                             2
# Cancellations                        1
# Checkouts                            7
# New_Bookings                         3
# ...

# %% [markdown]
# # Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                              Month   Weekday   Holiday  Marketing_Spend  \
# Month                     1.000000 -0.010121 -0.159064         0.012519
# Weekday                  -0.010121  1.000000  0.058732         0.022283
# Holiday                  -0.159064  0.058732  1.000000        -0.033041
# Marketing_Spend           0.012519  0.022283 -0.033041         1.000000
# Revenue                  -0.040698  0.033615 -0.012172         0.987278
# Room_Revenue             -0.346580  0.002421  0.053650         0.873177
# Occupancy_Rate           -0.186715  0.019129  0.020303         0.957134
# ADR                      -0.174598  0.043428  0.034726         0.935154
# RevPAR                   -0.449316  0.010915  0.094887         0.821076
# Available_Rooms          -0.230387  0.036955  0.021747         0.915673
# Reserved_Rooms            0.215157 -0.008412 -0.001113        -0.809496
# Market_Segment            0.136287 -0.018404 -0.008666        -0.773399
# ...

# %%
corr=df.corr(numeric_only=True)
fig = px.imshow(corr,text_auto=".4f",color_continuous_scale="RdBu_r",aspect="auto",title="Correlation Matrix", height=1000, width=1800)
fig.update_layout()
fig.show()

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df
# Out:
#      Month  Weekday  Holiday  Marketing_Spend  Revenue  Room_Revenue  \
# 0        1        1        1            50000    80000         45000
# 1        1        2        0            60000    85000         48000
# 2        1        3        0            70000    90000         49000
# 3        1        4        1            50000    80000         45000
# 4        1        5        0            60000    85000         48000
# ..     ...      ...      ...              ...      ...           ...
# 104      7        5        0            50000    78000         43000
# 105      7        6        0            55000    81000         44000
# 106      7        7        0            65000    87000         46000
# 107      7        1        0            70000    91000         48000
# 108      7        2        0            50000    78000         43000
#
#      Occupancy_Rate  ADR  RevPAR  Available_Rooms  ...  \
# 0              0.75  120   90.00               30  ...
# ...

# %% [markdown]
# # Hotel Performance Analysis

# %%
fig= px.scatter(df,x="Room_Revenue",y="Total_Revenue",color="Season",size="Occupancy_Rate",hover_data="Date",
                title="Hotel Performance Analysis") 
fig.show()

# %% [markdown]
# ## Hotel Performance Analysis
# - Evaluate overall hotel performance.
# - Analyze key performance indicators.
# - Compare revenue and occupancy trends.
# - Identify strengths and improvement areas.
# - Support better business decisions.

# %% [markdown]
# # Monthly Revenue Trend

# %%
fig = px.area(monthly,x="Month",y="Total_Revenue",title="Monthly Revenue trend")
fig.update_traces(line_shape="spline",mode="lines+markers")
fig.update_layout(template="plotly_white")
fig.show()

# %% [markdown]
# ### Monthly Revenue Trend – Bullet Points
# - Shows the monthly revenue performance of the hotel.
# - Revenue is highest in Month 1.
# - Revenue decreases during Months 2 and 3.
# - Revenue reaches its lowest point around Month 3.
# - Revenue gradually increases from Month 4 onwards.
# - Revenue recovers strongly by Month 7.

# %% [markdown]
# # Room Occupancy analysis

# %%
room_data={"Status":["Reserved Rooms","Available Rooms"],"Rooms":[df["Reserved_Rooms"].sum(),df["Available_Rooms"].sum()]}
fig = px.pie(room_data,names="Status",values="Rooms",title="Room Occupancy analysis")
fig.update_layout(title_x=0.5)
fig.show()

# %% [markdown]
# ## It helps analyze room utilization and understand occupancy levels in the hotel
# - Analyze room occupancy levels.
# - Compare reserved and available rooms.
# - Identify peak occupancy periods.
# - Detect room utilization trends.
# - Support efficient room management.

# %% [markdown]
# #  Revenue by season

# %%
fig = px.bar(df,x="Season",y="Total_Revenue",color="Season",title="Hotel Cost Analysis by Season")
fig.update_layout(title_x=0.5)
fig.show()

# %% [markdown]
# ## Season-wise Analysis
# - Monthly Total Cost Trend
# - Season and Month Cost Analysis
# - Hotel Cost Analysis by Season and Month
# - Monthly and Seasonal Cost Performance
# - Seasonal Revenue and Total Cost Analysis

# %% [markdown]
# # Cancellations Analysis trend

# %%
c = df.groupby("Month")["Cancellations"].sum().reset_index()

px.line(c, x="Month", y="Cancellations",
        title="Cancellation Analysis Trend",
        markers=True).update_traces(line_color="red").show()

# %% [markdown]
# ## Cancellations
# - Analyze booking cancellations.
# - Compare confirmed and cancelled bookings.
# - Identify cancellation trends.
# - Evaluate the impact on hotel revenue.
# - Support strategies to reduce cancellations

# %% [markdown]
# # Checkins Trend Over time

# %%
fig = px.pie(df, names="Checkins", values="New_Bookings",title="Checkins Trend over time")
fig.update_layout(title_x=0.5)
fig.show()

# %% [markdown]
# ### It help identity increasing,decresing or stable patterns in the date
#
# - Compare monthly check-ins.
# - Identify peak check-in periods.
# - Analyze guest arrival trends.nt

# %% [markdown]
# # Average Revenue:Weekday vs weekend

# %%
fig = px.bar(df,x="Weekday",y="Total_Revenue",color="Total_Revenue",color_continuous_scale="viridis",title="Average Revenue Weekday vs Weekend")
fig.show()

# %% [markdown]
# ### Average Revenue: Weekday vs Weekend – Bullet Points
# - Shows the average revenue generated on each weekday.
# - Revenue is relatively consistent across the week.
# - Some weekdays generate slightly higher average revenue than others.
# - No major difference is observed between weekdays.

# %% [markdown]
# # Hotel Checkout Activity

# %%
fig = px.area(df,x="Checkouts",y="Month",color="Checkouts", title="Hotel Checkout Activity")
fig.show()

# %% [markdown]
# ## The Hotel Checkout activity shows the number of guests checking out during different time periods or dates
# - Analyze hotel checkout trends.
# - Compare checkout activity over time.
# - Identify peak checkout periods.
# - Monitor guest departure patterns.
# - Support hotel operations and planning.

# %% [markdown]
# # Monthly Guest type analysis

# %%
plt.figure(figsize=(12,6))
sns.countplot(df,x="Month",hue="Guest_Type")
plt.title("Monthly Guest type analysis")
plt.xlabel("Month")
plt.ylabel("Number of Guests")
plt.show()

# %% [markdown]
# ## It helps campare different guest types on a mothly basis.
# - Analyze monthly guest type distribution.
# - Compare guest types across different months.
# - Identify peak months for each guest type.
# - Detect seasonal guest patterns.
# - Support targeted marketing strategies.

# %% [markdown]
# # Monthly Booking trend

# %%
fig = px.bar(df,x="Month",y="Bookings",color="Bookings",color_continuous_scale="Pinkyl",title="Monthly Booking Trend")
fig.show()

# %% [markdown]
# ### Monthly Booking Trend – Bullet Points
# - Shows the number of bookings for each month.
# - Month 1 has the highest number of bookings.
# - Bookings decrease during Months 2 and 3.
# - Bookings increase again toward the last month.
# - Helps identify seasonal booking patterns.

# %% [markdown]
# # Revenue by Channel(Hotel Substitute)

# %%
fig = px.bar(df, x="Booking_Channel",y="Total_Revenue",color="Booking_Channel",title="Revenue by channel(Hotel Substitute)")
fig.show()

# %% [markdown]
# ### If you need bullet points to explain this graph in your presentation:
#
# - Revenue is compared by Booking Channel.
# - Two booking channels are used: Direct and OTA.
# - Direct bookings generated the highest total revenue.
# - OTA bookings generated lower revenue than Direct bookings.
# - Direct channel contributes more to the hotel's overall income.

# %% [markdown]
# # Top 10 Revenue by country(City Substitute)

# %%
c = df.groupby("Guest_Country")["Total_Revenue"].sum().reset_index()
px.bar(c,x="Total_Revenue",y="Guest_Country",color="Total_Revenue",title="Top 10 Revenue by country(City Substitute)",
       orientation="h",color_continuous_scale="Blues").show()

# %% [markdown]
# # Revenue By Market segment

# %%
s = df.groupby("Market_Segment")["Total_Revenue"].sum().reset_index()

px.pie(s, names="Market_Segment", values="Total_Revenue",
       hole=0.4, title="Revenue by Market Segment").show()

# %% [markdown]
# ### Revenue by Market Segment
# - Shows the revenue contribution of each market segment.
# - The largest market segment generates the highest revenue.
# - Some segments contribute moderate revenue.
# - A few segments have low revenue contribution.
# - Helps identify the most profitable customer segments.

# %% [markdown]
# # Overall Costs distribution

# %%
profit= df.groupby("Date")["Profit"].sum().reset_index()
fig = px.bar(profit,x="Date",y="Profit",color="Profit",title="Overall Costs Distribution")
fig.show()
